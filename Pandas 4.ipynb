# %%
import pandas as pd

# %%
s=pd.Series()
s
# Out:
# <ipython-input-2-179794849e2b>:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s=pd.Series()
# Series([], dtype: float64)

# %%
d={'a':1,'b':2,'c':3}
s=pd.Series(d)
s
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
d={'a':1,'b':2,'c':3}
s=pd.Series(d,index=['a','b','c','d'])
s
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    NaN
# dtype: float64

# %%
d={'a':1,'b':2,'c':3}
s=pd.Series(d,index=['a','b'])
s
# Out:
# a    1
# b    2
# dtype: int64

# %%
s=pd.Series(5,index=[0,1,2,3,4,5])
s
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# 5    5
# dtype: int64

# %%
df=pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data=[['python',70],['Java',65],['C',67],['CPP',68]]
pd.DataFrame(data,columns=['Name','Age'])
# Out:
#      Name  Age
# 0  python   70
# 1    Java   65
# 2       C   67
# 3     CPP   68

# %%
data=[['python',70],['Java',65],['C',67],['CPP',68]]
pd.DataFrame(data,columns=['Name','Age','City'])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# C:\Python38\lib\site-packages\pandas\core\internals\construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     563     try:
# --> 564         columns = _validate_or_indexify_columns(content, columns)
#     565         result = _convert_object_array(content, dtype=dtype, coerce_float=coerce_float)
#
# C:\Python38\lib\site-packages\pandas\core\internals\construction.py in _validate_or_indexify_columns(content, columns)
#     687             # caller's responsibility to check for this...
# --> 688             raise AssertionError(
#     689                 f"{len(columns)} columns passed, passed data had "
#
# AssertionError: 3 columns passed, passed data had 2 columns
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
data=[{'a':1,'b':2},{'a':5,'b':7,'c':10}]
pd.DataFrame(data,index=['first','second'])
# Out:
#         a  b     c
# first   1  2   NaN
# second  5  7  10.0

# %%
data=[{'a':1,'b':2},{'a':5,'b':7,'c':10}]
df1=pd.DataFrame(data,index=['first','second'],columns=['a','b'])
print(df1)
df2=pd.DataFrame(data,index=['first','second'],columns=['a','b1'])
print(df2)
# Out:
#         a  b
# first   1  2
# second  5  7
#         a  b1
# first   1 NaN
# second  5 NaN

# %%
d={'one':pd.Series([1,2,3],index=['a','b','c']),
  'two':pd.Series([1,2,3,4],index=['a','b','c','d'])}
df1=pd.DataFrame(d)
print(df1)
df1['three']=df1['one']+df1['two']
df1
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4
#    one  two  three
# a  1.0    1    2.0
# b  2.0    2    4.0
# c  3.0    3    6.0
# d  NaN    4    NaN

# %%
d={'one':pd.Series([1,2,3],index=['a','b','c']),
  'two':pd.Series([1,2,3,4],index=['a','b','c','d'])}
df=pd.DataFrame(d)
print(df)
df['three']=pd.Series([10,20,30],index=['a','b','c'])
print(df)
df['four']=df['one']+df['three']
print(df)
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4
#    one  two  three
# a  1.0    1   10.0
# b  2.0    2   20.0
# c  3.0    3   30.0
# d  NaN    4    NaN
#    one  two  three  four
# a  1.0    1   10.0  11.0
# b  2.0    2   20.0  22.0
# c  3.0    3   30.0  33.0
# d  NaN    4    NaN   NaN

# %%
pd.read_csv('E:\Research Paper & Result\Dataset\Cholesterol.csv')
# Out:
#      age  sex  cp  trestbps  fbs  restecg  thalach  exang  oldpeak  slope ca  \
# 0     63    1   1       145    1        2      150      0      2.3      3  0
# 1     67    1   4       160    0        2      108      1      1.5      2  3
# 2     67    1   4       120    0        2      129      1      2.6      2  2
# 3     37    1   3       130    0        0      187      0      3.5      3  0
# 4     41    0   2       130    0        2      172      0      1.4      1  0
# ..   ...  ...  ..       ...  ...      ...      ...    ...      ...    ... ..
# 298   45    1   1       110    0        0      132      0      1.2      2  0
# 299   68    1   4       144    1        0      141      0      3.4      2  2
# 300   57    1   4       130    0        0      115      1      1.2      2  1
# 301   57    0   2       130    0        2      174      0      0.0      2  1
# 302   38    1   3       138    0        0      173      0      0.0      1  ?
#
#     thal  num  chol
# 0      6    0   233
# ...

# %%
df=pd.read_csv('E:\Research Paper & Result\Dataset\Cholesterol.csv',nrows=10)
df
# Out:
#    age  sex  cp  trestbps  fbs  restecg  thalach  exang  oldpeak  slope  ca  \
# 0   63    1   1       145    1        2      150      0      2.3      3   0
# 1   67    1   4       160    0        2      108      1      1.5      2   3
# 2   67    1   4       120    0        2      129      1      2.6      2   2
# 3   37    1   3       130    0        0      187      0      3.5      3   0
# 4   41    0   2       130    0        2      172      0      1.4      1   0
# 5   56    1   2       120    0        0      178      0      0.8      1   0
# 6   62    0   4       140    0        2      160      0      3.6      3   2
# 7   57    0   4       120    0        0      163      1      0.6      1   0
# 8   63    1   4       130    0        2      147      0      1.4      2   1
# 9   53    1   4       140    1        2      155      1      3.1      3   0
#
#    thal  num  chol
# 0     6    0   233
# 1     3    2   286
# 2     7    1   229
# 3     3    0   250
# 4     3    0   204
# ...

# %%
df=pd.read_csv('E:\Research Paper & Result\Dataset\Cholesterol.csv',usecols=[0,1,2,3,4])
df
# Out:
#      age  sex  cp  trestbps  fbs
# 0     63    1   1       145    1
# 1     67    1   4       160    0
# 2     67    1   4       120    0
# 3     37    1   3       130    0
# 4     41    0   2       130    0
# ..   ...  ...  ..       ...  ...
# 298   45    1   1       110    0
# 299   68    1   4       144    1
# 300   57    1   4       130    0
# 301   57    0   2       130    0
# 302   38    1   3       138    0
#
# [303 rows x 5 columns]

# %%
df=pd.read_csv('E:\Research Paper & Result\Dataset\Cholesterol.csv',usecols=['age','cp','fbs'])
df
# Out:
#      age  cp  fbs
# 0     63   1    1
# 1     67   4    0
# 2     67   4    0
# 3     37   3    0
# 4     41   2    0
# ..   ...  ..  ...
# 298   45   1    0
# 299   68   4    1
# 300   57   4    0
# 301   57   2    0
# 302   38   3    0
#
# [303 rows x 3 columns]

# %%
pd.read_csv('E:\Research Paper & Result\Dataset\Cholesterol.csv')
# Out:
#      age  sex  cp  trestbps  fbs  restecg  thalach  exang  oldpeak  slope ca  \
# 0     63    1   1       145    1        2      150      0      2.3      3  0
# 1     67    1   4       160    0        2      108      1      1.5      2  3
# 2     67    1   4       120    0        2      129      1      2.6      2  2
# 3     37    1   3       130    0        0      187      0      3.5      3  0
# 4     41    0   2       130    0        2      172      0      1.4      1  0
# ..   ...  ...  ..       ...  ...      ...      ...    ...      ...    ... ..
# 298   45    1   1       110    0        0      132      0      1.2      2  0
# 299   68    1   4       144    1        0      141      0      3.4      2  2
# 300   57    1   4       130    0        0      115      1      1.2      2  1
# 301   57    0   2       130    0        2      174      0      0.0      2  1
# 302   38    1   3       138    0        0      173      0      0.0      1  ?
#
#     thal  num  chol
# 0      6    0   233
# ...

# %%
pd.read_csv('E:\Research Paper & Result\Dataset\Cholesterol.csv').head(10)
# Out:
#    age  sex  cp  trestbps  fbs  restecg  thalach  exang  oldpeak  slope ca  \
# 0   63    1   1       145    1        2      150      0      2.3      3  0
# 1   67    1   4       160    0        2      108      1      1.5      2  3
# 2   67    1   4       120    0        2      129      1      2.6      2  2
# 3   37    1   3       130    0        0      187      0      3.5      3  0
# 4   41    0   2       130    0        2      172      0      1.4      1  0
# 5   56    1   2       120    0        0      178      0      0.8      1  0
# 6   62    0   4       140    0        2      160      0      3.6      3  2
# 7   57    0   4       120    0        0      163      1      0.6      1  0
# 8   63    1   4       130    0        2      147      0      1.4      2  1
# 9   53    1   4       140    1        2      155      1      3.1      3  0
#
#   thal  num  chol
# 0    6    0   233
# 1    3    2   286
# 2    7    1   229
# 3    3    0   250
# 4    3    0   204
# 5    3    0   236
# ...

# %%
pd.read_csv('E:\Research Paper & Result\Dataset\Cholesterol.csv',skiprows=[1,3])
# Out:
#      age  sex  cp  trestbps  fbs  restecg  thalach  exang  oldpeak  slope ca  \
# 0     67    1   4       160    0        2      108      1      1.5      2  3
# 1     37    1   3       130    0        0      187      0      3.5      3  0
# 2     41    0   2       130    0        2      172      0      1.4      1  0
# 3     56    1   2       120    0        0      178      0      0.8      1  0
# 4     62    0   4       140    0        2      160      0      3.6      3  2
# ..   ...  ...  ..       ...  ...      ...      ...    ...      ...    ... ..
# 296   45    1   1       110    0        0      132      0      1.2      2  0
# 297   68    1   4       144    1        0      141      0      3.4      2  2
# 298   57    1   4       130    0        0      115      1      1.2      2  1
# 299   57    0   2       130    0        2      174      0      0.0      2  1
# 300   38    1   3       138    0        0      173      0      0.0      1  ?
#
#     thal  num  chol
# 0      3    2   286
# ...

# %%
pd.read_csv('E:\Research Paper & Result\Dataset\Cholesterol.csv',index_col='fbs')
# Out:
#      age  sex  cp  trestbps  restecg  thalach  exang  oldpeak  slope ca thal  \
# fbs
# 1     63    1   1       145        2      150      0      2.3      3  0    6
# 0     67    1   4       160        2      108      1      1.5      2  3    3
# 0     67    1   4       120        2      129      1      2.6      2  2    7
# 0     37    1   3       130        0      187      0      3.5      3  0    3
# 0     41    0   2       130        2      172      0      1.4      1  0    3
# ..   ...  ...  ..       ...      ...      ...    ...      ...    ... ..  ...
# 0     45    1   1       110        0      132      0      1.2      2  0    7
# 1     68    1   4       144        0      141      0      3.4      2  2    7
# 0     57    1   4       130        0      115      1      1.2      2  1    7
# 0     57    0   2       130        2      174      0      0.0      2  1    3
# 0     38    1   3       138        0      173      0      0.0      1  ?    3
#
#      num  chol
# fbs
# 1      0   233
# ...

# %%
pd.read_csv('E:\Research Paper & Result\Dataset\Cholesterol.csv',index_col=0)
# Out:
#      sex  cp  trestbps  fbs  restecg  thalach  exang  oldpeak  slope ca thal  \
# age
# 63     1   1       145    1        2      150      0      2.3      3  0    6
# 67     1   4       160    0        2      108      1      1.5      2  3    3
# 67     1   4       120    0        2      129      1      2.6      2  2    7
# 37     1   3       130    0        0      187      0      3.5      3  0    3
# 41     0   2       130    0        2      172      0      1.4      1  0    3
# ..   ...  ..       ...  ...      ...      ...    ...      ...    ... ..  ...
# 45     1   1       110    0        0      132      0      1.2      2  0    7
# 68     1   4       144    1        0      141      0      3.4      2  2    7
# 57     1   4       130    0        0      115      1      1.2      2  1    7
# 57     0   2       130    0        2      174      0      0.0      2  1    3
# 38     1   3       138    0        0      173      0      0.0      1  ?    3
#
#      num  chol
# age
# 63     0   233
# ...

# %%
pd.read_csv('E:\Research Paper & Result\Dataset\Cholesterol.csv',header=3)
# Out:
#      age  sex  cp  trestbps  fbs  restecg  thalach  exang  oldpeak  slope ca  \
# 0     63    1   1       145    1        2      150      0      2.3      3  0
# 1     67    1   4       160    0        2      108      1      1.5      2  3
# 2     67    1   4       120    0        2      129      1      2.6      2  2
# 3     37    1   3       130    0        0      187      0      3.5      3  0
# 4     41    0   2       130    0        2      172      0      1.4      1  0
# ..   ...  ...  ..       ...  ...      ...      ...    ...      ...    ... ..
# 298   45    1   1       110    0        0      132      0      1.2      2  0
# 299   68    1   4       144    1        0      141      0      3.4      2  2
# 300   57    1   4       130    0        0      115      1      1.2      2  1
# 301   57    0   2       130    0        2      174      0      0.0      2  1
# 302   38    1   3       138    0        0      173      0      0.0      1  ?
#
#     thal  num  chol
# 0      6    0   233
# ...

# %%
pd.read_csv('E:\Research Paper & Result\Dataset\Cholesterol.csv',header=None)
# Out:
#          0     1    2         3    4        5        6      7        8   \
# 0    Center   NaN  NaN       NaN  NaN      NaN      NaN    NaN      NaN
# 1       NaN  Data  NaN       NaN  NaN      NaN      NaN    NaN      NaN
# 2       NaN   NaN  NaN       NaN  NaN      NaN      NaN    NaN      NaN
# 3       age   sex   cp  trestbps  fbs  restecg  thalach  exang  oldpeak
# 4        63     1    1       145    1        2      150      0      2.3
# ..      ...   ...  ...       ...  ...      ...      ...    ...      ...
# 302      45     1    1       110    0        0      132      0      1.2
# 303      68     1    4       144    1        0      141      0      3.4
# 304      57     1    4       130    0        0      115      1      1.2
# 305      57     0    2       130    0        2      174      0        0
# 306      38     1    3       138    0        0      173      0        0
#
#         9    10    11   12    13
# 0      NaN  NaN   NaN  NaN   NaN
# 1      NaN  NaN   NaN  NaN   NaN
# ...

# %%
pd.read_csv('E:\Research Paper & Result\Dataset\Cholesterol.csv',header=None,prefix='Col')
# Out:
#        Col0  Col1 Col2      Col3 Col4     Col5     Col6   Col7     Col8  \
# 0    Center   NaN  NaN       NaN  NaN      NaN      NaN    NaN      NaN
# 1       NaN  Data  NaN       NaN  NaN      NaN      NaN    NaN      NaN
# 2       NaN   NaN  NaN       NaN  NaN      NaN      NaN    NaN      NaN
# 3       age   sex   cp  trestbps  fbs  restecg  thalach  exang  oldpeak
# 4        63     1    1       145    1        2      150      0      2.3
# ..      ...   ...  ...       ...  ...      ...      ...    ...      ...
# 302      45     1    1       110    0        0      132      0      1.2
# 303      68     1    4       144    1        0      141      0      3.4
# 304      57     1    4       130    0        0      115      1      1.2
# 305      57     0    2       130    0        2      174      0        0
# 306      38     1    3       138    0        0      173      0        0
#
#       Col9 Col10 Col11 Col12 Col13
# 0      NaN   NaN   NaN   NaN   NaN
# ...

# %%
pd.read_csv('E:\Research Paper & Result\Dataset\Cholesterol.csv',names=['A','B','C','D','E','F','A1','B1','C1','D1','E1','F1','G','G1'])
# Out:
#        A    B   C         D    E        F       A1     B1       C1     D1  E1  \
# 0    age  sex  cp  trestbps  fbs  restecg  thalach  exang  oldpeak  slope  ca
# 1     63    1   1       145    1        2      150      0      2.3      3   0
# 2     67    1   4       160    0        2      108      1      1.5      2   3
# 3     67    1   4       120    0        2      129      1      2.6      2   2
# 4     37    1   3       130    0        0      187      0      3.5      3   0
# ..   ...  ...  ..       ...  ...      ...      ...    ...      ...    ...  ..
# 299   45    1   1       110    0        0      132      0      1.2      2   0
# 300   68    1   4       144    1        0      141      0      3.4      2   2
# 301   57    1   4       130    0        0      115      1      1.2      2   1
# 302   57    0   2       130    0        2      174      0        0      2   1
# 303   38    1   3       138    0        0      173      0        0      1   ?
#
#        F1    G    G1
# ...

# %%
pd.read_csv('E:\Research Paper & Result\Dataset\Cholesterol.csv')
# Out:
#      age  sex  cp  trestbps  fbs  restecg  thalach  exang  oldpeak  slope ca  \
# 0     63    1   1       145    1        2      150      0      2.3      3  0
# 1     67    1   4       160    0        2      108      1      1.5      2  3
# 2     67    1   4       120    0        2      129      1      2.6      2  2
# 3     37    1   3       130    0        0      187      0      3.5      3  0
# 4     41    0   2       130    0        2      172      0      1.4      1  0
# ..   ...  ...  ..       ...  ...      ...      ...    ...      ...    ... ..
# 298   45    1   1       110    0        0      132      0      1.2      2  0
# 299   68    1   4       144    1        0      141      0      3.4      2  2
# 300   57    1   4       130    0        0      115      1      1.2      2  1
# 301   57    0   2       130    0        2      174      0      0.0      2  1
# 302   38    1   3       138    0        0      173      0      0.0      1  ?
#
#     thal  num  chol
# 0      6    0   233
# ...

# %%
pd.read_csv('E:\Research Paper & Result\Dataset\Cholesterol.csv',dtype={'age':'float64','fbs':'float64'})
# Out:
#       age  sex  cp  trestbps  fbs  restecg  thalach  exang  oldpeak  slope ca  \
# 0    63.0    1   1       145  1.0        2      150      0      2.3      3  0
# 1    67.0    1   4       160  0.0        2      108      1      1.5      2  3
# 2    67.0    1   4       120  0.0        2      129      1      2.6      2  2
# 3    37.0    1   3       130  0.0        0      187      0      3.5      3  0
# 4    41.0    0   2       130  0.0        2      172      0      1.4      1  0
# ..    ...  ...  ..       ...  ...      ...      ...    ...      ...    ... ..
# 298  45.0    1   1       110  0.0        0      132      0      1.2      2  0
# 299  68.0    1   4       144  1.0        0      141      0      3.4      2  2
# 300  57.0    1   4       130  0.0        0      115      1      1.2      2  1
# 301  57.0    0   2       130  0.0        2      174      0      0.0      2  1
# 302  38.0    1   3       138  0.0        0      173      0      0.0      1  ?
#
#     thal  num  chol
# ...

# %%
pd.read_csv('E:\Research Paper & Result\Dataset\Cholesterol.csv',true_values=['yes'])
# Out:
#      age  sex  cp  Date  trestbps  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1  True       145    1        2      150      0      2.3
# 1     67    1   4  True       160    0        2      108      1      1.5
# 2     67    1   4  True       120    0        2      129      1      2.6
# 3     37    1   3  True       130    0        0      187      0      3.5
# 4     41    0   2  True       130    0        2      172      0      1.4
# ..   ...  ...  ..   ...       ...  ...      ...      ...    ...      ...
# 298   45    1   1  True       110    0        0      132      0      1.2
# 299   68    1   4  True       144    1        0      141      0      3.4
# 300   57    1   4  True       130    0        0      115      1      1.2
# 301   57    0   2  True       130    0        2      174      0      0.0
# 302   38    1   3  True       138    0        0      173      0      0.0
#
#      slope ca thal  num  chol
# 0        3  0    6    0   233
# ...

# %%
pd.read_csv('E:\Research Paper & Result\Dataset\Cholesterol.csv',true_values=['yes','Yes','YES'],false_values=['no'],nrows=20)
# Out:
#     age  sex  cp   Date  trestbps  fbs  restecg  thalach  exang  oldpeak  \
# 0    63    1   1   True       145    1        2      150      0      2.3
# 1    67    1   4  False       160    0        2      108      1      1.5
# 2    67    1   4   True       120    0        2      129      1      2.6
# 3    37    1   3   True       130    0        0      187      0      3.5
# 4    41    0   2   True       130    0        2      172      0      1.4
# 5    56    1   2   True       120    0        0      178      0      0.8
# 6    62    0   4  False       140    0        2      160      0      3.6
# 7    57    0   4   True       120    0        0      163      1      0.6
# 8    63    1   4   True       130    0        2      147      0      1.4
# 9    53    1   4  False       140    1        2      155      1      3.1
# 10   57    1   4   True       140    0        0      148      0      0.4
# 11   56    0   2   True       140    0        2      153      0      1.3
# ...
